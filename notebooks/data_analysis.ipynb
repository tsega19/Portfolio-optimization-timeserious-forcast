# %% [markdown]
# ## Task 1: Financial Data Analysis Script
# This notebook performs comprehensive analysis of financial data for TSLA, BND, and SPY.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

import warnings
warnings.filterwarnings('ignore')

# %%
# Add the parent directory to the system path 
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.data_analysis import *

# %%
#  Data Collection
start_date = '2015-01-01'
end_date = '2024-12-31'
tickers = ['TSLA', 'BND', 'SPY']

# %%
# Fetch data for all assets
data_dict = {}
for ticker in tickers:
    data_dict[ticker] = fetch_stock_data(ticker, start_date, end_date)
    print(f"Fetched data for {ticker}")
# Out:
# Fetched data for TSLA
# Fetched data for BND
# Fetched data for SPY

# %%
data_dict
# Out:
# {'TSLA':                                  Open        High         Low       Close  \
#  Date
#  2015-01-02 00:00:00-05:00   14.858000   14.883333   14.217333   14.620667
#  2015-01-05 00:00:00-05:00   14.303333   14.433333   13.810667   14.006000
#  2015-01-06 00:00:00-05:00   14.004000   14.280000   13.614000   14.085333
#  2015-01-07 00:00:00-05:00   14.223333   14.318667   13.985333   14.063333
#  2015-01-08 00:00:00-05:00   14.187333   14.253333   14.000667   14.041333
#  ...                               ...         ...         ...         ...
#  2024-11-12 00:00:00-05:00  342.739990  345.839996  323.309998  328.489990
#  2024-11-13 00:00:00-05:00  335.850006  344.600006  322.500000  330.239990
#  2024-11-14 00:00:00-05:00  327.690002  329.980011  310.369995  311.179993
#  2024-11-15 00:00:00-05:00  310.570007  324.679993  309.220001  320.720001
#  2024-11-18 00:00:00-05:00  340.730011  348.549988  330.010010  338.739990
#
#                                Volume  Dividends  Stock Splits
#  Date
#  2015-01-02 00:00:00-05:00   71466000        0.0           0.0
#  2015-01-05 00:00:00-05:00   80527500        0.0           0.0
#  2015-01-06 00:00:00-05:00   93928500        0.0           0.0
#  2015-01-07 00:00:00-05:00   44526000        0.0           0.0
#  2015-01-08 00:00:00-05:00   51637500        0.0           0.0
#  ...                              ...        ...           ...
#  2024-11-12 00:00:00-05:00  155726000        0.0           0.0
#  2024-11-13 00:00:00-05:00  125405600        0.0           0.0
#  2024-11-14 00:00:00-05:00  120726100        0.0           0.0
#  2024-11-15 00:00:00-05:00  114440300        0.0           0.0
#  2024-11-18 00:00:00-05:00  126085600        0.0           0.0
#
#  [2487 rows x 7 columns],
#  'BND':                                 Open       High        Low      Close  \
#  Date
#  2015-01-02 00:00:00-05:00  63.004189  63.202918  62.996544  63.172344
#  2015-01-05 00:00:00-05:00  63.241126  63.378707  63.210552  63.355778
#  2015-01-06 00:00:00-05:00  63.462760  63.730276  63.462760  63.539192
#  2015-01-07 00:00:00-05:00  63.546834  63.653840  63.478046  63.577408
#  2015-01-08 00:00:00-05:00  63.523905  63.523905  63.416898  63.478046
#  ...                              ...        ...        ...        ...
#  2024-11-12 00:00:00-05:00  72.739998  72.820000  72.459999  72.510002
#  2024-11-13 00:00:00-05:00  72.919998  72.919998  72.410004  72.480003
#  2024-11-14 00:00:00-05:00  72.599998  72.720001  72.410004  72.459999
#  2024-11-15 00:00:00-05:00  72.339996  72.660004  72.199997  72.480003
#  2024-11-18 00:00:00-05:00  72.400002  72.610001  72.330002  72.550003
#
#                               Volume  Dividends  Stock Splits  Capital Gains
#  Date
#  2015-01-02 00:00:00-05:00   2218800        0.0           0.0            0.0
#  2015-01-05 00:00:00-05:00   5820100        0.0           0.0            0.0
#  2015-01-06 00:00:00-05:00   3887600        0.0           0.0            0.0
#  2015-01-07 00:00:00-05:00   2433400        0.0           0.0            0.0
#  2015-01-08 00:00:00-05:00   1873400        0.0           0.0            0.0
#  ...                             ...        ...           ...            ...
#  2024-11-12 00:00:00-05:00   7197800        0.0           0.0            0.0
#  2024-11-13 00:00:00-05:00   5458100        0.0           0.0            0.0
#  2024-11-14 00:00:00-05:00   6643300        0.0           0.0            0.0
#  2024-11-15 00:00:00-05:00  18467300        0.0           0.0            0.0
#  2024-11-18 00:00:00-05:00   4964800        0.0           0.0            0.0
#
#  [2487 rows x 8 columns],
#  'SPY':                                  Open        High         Low       Close  \
#  Date
#  2015-01-02 00:00:00-05:00  173.974641  174.396132  172.120070  173.173798
#  2015-01-05 00:00:00-05:00  172.111583  172.280176  169.734381  170.046280
#  2015-01-06 00:00:00-05:00  170.358216  170.889299  167.635388  168.444656
#  2015-01-07 00:00:00-05:00  169.793387  170.889266  169.338182  170.543640
#  2015-01-08 00:00:00-05:00  171.976772  173.789191  171.959921  173.570007
#  ...                               ...         ...         ...         ...
#  2024-11-12 00:00:00-05:00  598.679993  599.289978  594.369995  596.900024
#  2024-11-13 00:00:00-05:00  597.369995  599.229980  594.960022  597.190002
#  2024-11-14 00:00:00-05:00  597.320007  597.809998  592.650024  593.349976
#  2024-11-15 00:00:00-05:00  589.719971  590.200012  583.859985  585.750000
#  2024-11-18 00:00:00-05:00  586.219971  589.489990  585.340027  588.150024
#
#                                Volume  Dividends  Stock Splits  Capital Gains
#  Date
#  2015-01-02 00:00:00-05:00  121465900        0.0           0.0            0.0
#  2015-01-05 00:00:00-05:00  169632600        0.0           0.0            0.0
#  2015-01-06 00:00:00-05:00  209151400        0.0           0.0            0.0
#  2015-01-07 00:00:00-05:00  125346700        0.0           0.0            0.0
#  2015-01-08 00:00:00-05:00  147217800        0.0           0.0            0.0
#  ...                              ...        ...           ...            ...
#  2024-11-12 00:00:00-05:00   43006100        0.0           0.0            0.0
#  2024-11-13 00:00:00-05:00   47388600        0.0           0.0            0.0
#  2024-11-14 00:00:00-05:00   38904100        0.0           0.0            0.0
#  2024-11-15 00:00:00-05:00   75988800        0.0           0.0            0.0
#  2024-11-18 00:00:00-05:00   37001700        0.0           0.0            0.0
#
#  [2487 rows x 8 columns]}

# %%
# Data Cleaning and Preprocessing
print("\n Data Cleaning and Preprocessing")
print("-" * 40)
    
cleaned_data = {}
for ticker in tickers:
    cleaned_data[ticker], missing_values = clean_data(data_dict[ticker], ticker)
    print(f"\nProcessed data for {ticker}")
    print("Missing values:")
    print(missing_values)
    print("\nBasic statistics:")
    print(cleaned_data[ticker]['Close'].describe())
# Out:
#  Data Cleaning and Preprocessing
# ----------------------------------------
#
# Processed data for TSLA
# Missing values:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
#
# Basic statistics:
# count    2487.000000
# mean      112.416220
# std       110.688731
# min         9.578000
# 25%        17.126333
# 50%        25.304667
# 75%       218.359993
# max       409.970001
# Name: Close, dtype: float64
#
# Processed data for BND
# Missing values:
# Open             0
# High             0
# Low              0
# Close            0
# Volume           0
# Dividends        0
# Stock Splits     0
# Capital Gains    0
# dtype: int64
#
# Basic statistics:
# count    2487.000000
# mean       69.899658
# std         4.868438
# min        62.453266
# 25%        66.146492
# 50%        68.727852
# 75%        73.591248
# max        79.578110
# Name: Close, dtype: float64
#
# Processed data for SPY
# Missing values:
# Open             0
# High             0
# Low              0
# Close            0
# Volume           0
# Dividends        0
# Stock Splits     0
# Capital Gains    0
# dtype: int64
#
# Basic statistics:
# count    2487.000000
# mean      311.699813
# std       112.743371
# min       157.328598
# 25%       215.025269
# 50%       276.228821
# 75%       403.131256
# max       598.760010
# Name: Close, dtype: float64

# %%
# Price Analysis
print("Price Analysis")
print("-" * 40)
    
for ticker in tickers:
    print(f"\nAnalyzing price trends for {ticker}")
    plot_price_analysis(cleaned_data[ticker], ticker)
    plt.close()
# Out:
# Price Analysis
# ----------------------------------------
#
# Analyzing price trends for TSLA
# Analyzing price trends for BND
# Analyzing price trends for SPY

# %%
# Returns Analysis
print("Returns Analysis")
print("-" * 40)
    
for ticker in tickers:
    print(f"\nAnalyzing returns distribution for {ticker}")
    plot_returns_distribution(cleaned_data[ticker], ticker)
    plt.close()
# Out:
# Returns Analysis
# ----------------------------------------
#
# Analyzing returns distribution for TSLA
# Analyzing returns distribution for BND
# Analyzing returns distribution for SPY

# %%
# Risk Analysis
print("Risk Analysis")
print("-" * 40)
    
risk_metrics = {}
for ticker in tickers:
    risk_metrics[ticker] = calculate_risk_metrics(cleaned_data[ticker])
    print(f"\nRisk Metrics for {ticker}:")
    for metric, value in risk_metrics[ticker].items():
        print(f"{metric}: {value:.4f}")
        
    print(f"\nPlotting rolling volatility for {ticker}")
    plot_rolling_volatility(cleaned_data[ticker], ticker)
    plt.close()
# Out:
# Risk Analysis
# ----------------------------------------
#
# Risk Metrics for TSLA:
# VaR_95: -0.0515
# VaR_99: -0.0903
# Daily_Volatility: 0.0360
# Annual_Volatility: 0.5713
# Skewness: 0.2816
# Kurtosis: 4.4659
# Sharpe_Ratio: 0.8073
# Max_Drawdown: -0.7363
#
# Plotting rolling volatility for TSLA
# Risk Metrics for BND:
# VaR_95: -0.0048
# VaR_99: -0.0087
# Daily_Volatility: 0.0034
# Annual_Volatility: 0.0545
# Skewness: -0.9667
# Kurtosis: 38.1791
# Sharpe_Ratio: -0.0822
# Max_Drawdown: -0.1858
#
# Plotting rolling volatility for BND
# Risk Metrics for SPY:
# VaR_95: -0.0168
# VaR_99: -0.0321
# Daily_Volatility: 0.0111
# Annual_Volatility: 0.1767
# Skewness: -0.5498
# Kurtosis: 12.7316
# Sharpe_Ratio: 0.6771
# Max_Drawdown: -0.3372
#
# Plotting rolling volatility for SPY

# %%
# Seasonality Analysis
print("Seasonality Analysis")
print("-" * 40)
    
print("\nPerforming seasonality analysis for Tesla")
decomposition = perform_seasonality_analysis(cleaned_data['TSLA'], 'TSLA')
plt.close()
# Out:
# Seasonality Analysis
# ----------------------------------------
#
# Performing seasonality analysis for Tesla

# %%
# Correlation Analysis
print("Correlation Analysis")
print("-" * 40)
    
correlation_matrix = analyze_correlations(cleaned_data)
print("\nCorrelation Matrix:")
print(correlation_matrix)
plt.close()
# Out:
# Correlation Analysis
# ----------------------------------------
# Correlation Matrix:
#           TSLA       BND       SPY
# TSLA  1.000000  0.055249  0.465196
# BND   0.055249  1.000000  0.105523
# SPY   0.465196  0.105523  1.000000

# %%
# Save Processed Data
print("Saving Processed Data")
print("-" * 40)

output_folder = "../data/processed/"
for ticker, df in cleaned_data.items():
    df.to_csv(f'{output_folder}{ticker}_processed.csv',index='Date')
    print(f"Saved processed data for {ticker} in {output_folder}")
# Out:
# Saving Processed Data
# ----------------------------------------
# Saved processed data for TSLA in ../data/processed/
# Saved processed data for BND in ../data/processed/
# Saved processed data for SPY in ../data/processed/

# %%
for ticker, df in cleaned_data.items():
    print(f"\nData for {ticker}:")
    print(df.head())  # Show the first 5 rows
# Out:
# Data for TSLA:
#                                 Open       High        Low      Close  \
# Date
# 2015-01-02 00:00:00-05:00  14.858000  14.883333  14.217333  14.620667
# 2015-01-05 00:00:00-05:00  14.303333  14.433333  13.810667  14.006000
# 2015-01-06 00:00:00-05:00  14.004000  14.280000  13.614000  14.085333
# 2015-01-07 00:00:00-05:00  14.223333  14.318667  13.985333  14.063333
# 2015-01-08 00:00:00-05:00  14.187333  14.253333  14.000667  14.041333
#
#                              Volume  Dividends  Stock Splits  Daily_Return  \
# Date
# 2015-01-02 00:00:00-05:00  71466000        0.0           0.0           NaN
# 2015-01-05 00:00:00-05:00  80527500        0.0           0.0     -0.042041
# 2015-01-06 00:00:00-05:00  93928500        0.0           0.0      0.005664
# 2015-01-07 00:00:00-05:00  44526000        0.0           0.0     -0.001562
# 2015-01-08 00:00:00-05:00  51637500        0.0           0.0     -0.001564
#
#                            MA20  MA50  MA200  Volatility
# Date
# 2015-01-02 00:00:00-05:00   NaN   NaN    NaN         NaN
# 2015-01-05 00:00:00-05:00   NaN   NaN    NaN         NaN
# 2015-01-06 00:00:00-05:00   NaN   NaN    NaN         NaN
# 2015-01-07 00:00:00-05:00   NaN   NaN    NaN         NaN
# 2015-01-08 00:00:00-05:00   NaN   NaN    NaN         NaN
#
# Data for BND:
#                                 Open       High        Low      Close  \
# Date
# 2015-01-02 00:00:00-05:00  63.004189  63.202918  62.996544  63.172344
# 2015-01-05 00:00:00-05:00  63.241126  63.378707  63.210552  63.355778
# 2015-01-06 00:00:00-05:00  63.462760  63.730276  63.462760  63.539192
# 2015-01-07 00:00:00-05:00  63.546834  63.653840  63.478046  63.577408
# 2015-01-08 00:00:00-05:00  63.523905  63.523905  63.416898  63.478046
#
#                             Volume  Dividends  Stock Splits  Capital Gains  \
# Date
# 2015-01-02 00:00:00-05:00  2218800        0.0           0.0            0.0
# 2015-01-05 00:00:00-05:00  5820100        0.0           0.0            0.0
# 2015-01-06 00:00:00-05:00  3887600        0.0           0.0            0.0
# 2015-01-07 00:00:00-05:00  2433400        0.0           0.0            0.0
# 2015-01-08 00:00:00-05:00  1873400        0.0           0.0            0.0
#
#                            Daily_Return  MA20  MA50  MA200  Volatility
# Date
# 2015-01-02 00:00:00-05:00           NaN   NaN   NaN    NaN         NaN
# 2015-01-05 00:00:00-05:00      0.002904   NaN   NaN    NaN         NaN
# 2015-01-06 00:00:00-05:00      0.002895   NaN   NaN    NaN         NaN
# 2015-01-07 00:00:00-05:00      0.000601   NaN   NaN    NaN         NaN
# 2015-01-08 00:00:00-05:00     -0.001563   NaN   NaN    NaN         NaN
#
# Data for SPY:
#                                  Open        High         Low       Close  \
# Date
# 2015-01-02 00:00:00-05:00  173.974641  174.396132  172.120070  173.173798
# 2015-01-05 00:00:00-05:00  172.111583  172.280176  169.734381  170.046280
# 2015-01-06 00:00:00-05:00  170.358216  170.889299  167.635388  168.444656
# 2015-01-07 00:00:00-05:00  169.793387  170.889266  169.338182  170.543640
# 2015-01-08 00:00:00-05:00  171.976772  173.789191  171.959921  173.570007
#
#                               Volume  Dividends  Stock Splits  Capital Gains  \
# Date
# 2015-01-02 00:00:00-05:00  121465900        0.0           0.0            0.0
# 2015-01-05 00:00:00-05:00  169632600        0.0           0.0            0.0
# 2015-01-06 00:00:00-05:00  209151400        0.0           0.0            0.0
# 2015-01-07 00:00:00-05:00  125346700        0.0           0.0            0.0
# 2015-01-08 00:00:00-05:00  147217800        0.0           0.0            0.0
#
#                            Daily_Return  MA20  MA50  MA200  Volatility
# Date
# 2015-01-02 00:00:00-05:00           NaN   NaN   NaN    NaN         NaN
# 2015-01-05 00:00:00-05:00     -0.018060   NaN   NaN    NaN         NaN
# 2015-01-06 00:00:00-05:00     -0.009419   NaN   NaN    NaN         NaN
# 2015-01-07 00:00:00-05:00      0.012461   NaN   NaN    NaN         NaN
# 2015-01-08 00:00:00-05:00      0.017745   NaN   NaN    NaN         NaN

# %%
for ticker, df in cleaned_data.items():
    print(f"\nInfo for {ticker}:")
    print(df.info())
# Out:
# Info for TSLA:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2487 entries, 2015-01-02 00:00:00-05:00 to 2024-11-18 00:00:00-05:00
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2487 non-null   float64
#  1   High          2487 non-null   float64
#  2   Low           2487 non-null   float64
#  3   Close         2487 non-null   float64
#  4   Volume        2487 non-null   int64
#  5   Dividends     2487 non-null   float64
#  6   Stock Splits  2487 non-null   float64
#  7   Daily_Return  2486 non-null   float64
#  8   MA20          2468 non-null   float64
#  9   MA50          2438 non-null   float64
#  10  MA200         2288 non-null   float64
#  11  Volatility    2467 non-null   float64
# dtypes: float64(11), int64(1)
# memory usage: 252.6 KB
# None
#
# Info for BND:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2487 entries, 2015-01-02 00:00:00-05:00 to 2024-11-18 00:00:00-05:00
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Open           2487 non-null   float64
#  1   High           2487 non-null   float64
#  2   Low            2487 non-null   float64
#  3   Close          2487 non-null   float64
#  4   Volume         2487 non-null   int64
#  5   Dividends      2487 non-null   float64
#  6   Stock Splits   2487 non-null   float64
#  7   Capital Gains  2487 non-null   float64
#  8   Daily_Return   2486 non-null   float64
#  9   MA20           2468 non-null   float64
#  10  MA50           2438 non-null   float64
#  11  MA200          2288 non-null   float64
#  12  Volatility     2467 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 272.0 KB
# None
#
# Info for SPY:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2487 entries, 2015-01-02 00:00:00-05:00 to 2024-11-18 00:00:00-05:00
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Open           2487 non-null   float64
#  1   High           2487 non-null   float64
#  2   Low            2487 non-null   float64
#  3   Close          2487 non-null   float64
#  4   Volume         2487 non-null   int64
#  5   Dividends      2487 non-null   float64
#  6   Stock Splits   2487 non-null   float64
#  7   Capital Gains  2487 non-null   float64
#  8   Daily_Return   2486 non-null   float64
#  9   MA20           2468 non-null   float64
#  10  MA50           2438 non-null   float64
#  11  MA200          2288 non-null   float64
#  12  Volatility     2467 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 272.0 KB
# None

# %%
# Summary Report
print("\n Summary of Findings")
print("-" * 40)
    
generate_summary_report(cleaned_data, risk_metrics, correlation_matrix)
# Out:
#  Summary of Findings
# ----------------------------------------
#
# Analysis Summary:
# ----------------------------------------
# Price Analysis:
# - TSLA: Current Price: $338.74, Total Return: 2216.86%
# - BND: Current Price: $72.55, Total Return: 14.84%
# - SPY: Current Price: $588.15, Total Return: 239.63%
#
# Risk Analysis:
# - TSLA:
#   * Annual Volatility: 57.13%
#   * Sharpe Ratio: 0.81
#   * Maximum Drawdown: -73.63%
# - BND:
#   * Annual Volatility: 5.45%
#   * Sharpe Ratio: -0.08
#   * Maximum Drawdown: -18.58%
# - SPY:
#   * Annual Volatility: 17.67%
#   * Sharpe Ratio: 0.68
#   * Maximum Drawdown: -33.72%
#
# Correlation Analysis:

# %%
df_TSLA=pd.read_csv('../data/processed/TSLA_processed.csv')
df_SPY=pd.read_csv('../data/processed/SPY_processed.csv')
df_BND=pd.read_csv('../data/processed/BND_processed.csv')

# %%
df_TSLA.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2015-01-02 00:00:00-05:00  14.858000  14.883333  14.217333  14.620667
# 1  2015-01-05 00:00:00-05:00  14.303333  14.433333  13.810667  14.006000
# 2  2015-01-06 00:00:00-05:00  14.004000  14.280000  13.614000  14.085333
# 3  2015-01-07 00:00:00-05:00  14.223333  14.318667  13.985333  14.063333
# 4  2015-01-08 00:00:00-05:00  14.187333  14.253333  14.000667  14.041333
#
#      Volume  Dividends  Stock Splits  Daily_Return  MA20  MA50  MA200  \
# 0  71466000        0.0           0.0           NaN   NaN   NaN    NaN
# 1  80527500        0.0           0.0     -0.042041   NaN   NaN    NaN
# 2  93928500        0.0           0.0      0.005664   NaN   NaN    NaN
# 3  44526000        0.0           0.0     -0.001562   NaN   NaN    NaN
# 4  51637500        0.0           0.0     -0.001564   NaN   NaN    NaN
#
#    Volatility
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
print(df_TSLA.isnull().sum())
# Out:
# Date              0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# Dividends         0
# Stock Splits      0
# Daily_Return      1
# MA20             19
# MA50             49
# MA200           199
# Volatility       20
# dtype: int64

# %%
df_BND.head()
# Out:
#                         Date       Open       High        Low      Close  \
# 0  2015-01-02 00:00:00-05:00  63.004189  63.202918  62.996544  63.172344
# 1  2015-01-05 00:00:00-05:00  63.241126  63.378707  63.210552  63.355778
# 2  2015-01-06 00:00:00-05:00  63.462760  63.730276  63.462760  63.539192
# 3  2015-01-07 00:00:00-05:00  63.546834  63.653840  63.478046  63.577408
# 4  2015-01-08 00:00:00-05:00  63.523905  63.523905  63.416898  63.478046
#
#     Volume  Dividends  Stock Splits  Capital Gains  Daily_Return  MA20  MA50  \
# 0  2218800        0.0           0.0            0.0           NaN   NaN   NaN
# 1  5820100        0.0           0.0            0.0      0.002904   NaN   NaN
# 2  3887600        0.0           0.0            0.0      0.002895   NaN   NaN
# 3  2433400        0.0           0.0            0.0      0.000601   NaN   NaN
# 4  1873400        0.0           0.0            0.0     -0.001563   NaN   NaN
#
#    MA200  Volatility
# 0    NaN         NaN
# 1    NaN         NaN
# 2    NaN         NaN
# 3    NaN         NaN
# 4    NaN         NaN

# %%
df_BND.isnull().sum()
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Volume             0
# Dividends          0
# Stock Splits       0
# Capital Gains      0
# Daily_Return       1
# MA20              19
# MA50              49
# MA200            199
# Volatility        20
# dtype: int64

# %%
df_SPY.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2015-01-02 00:00:00-05:00  173.974641  174.396132  172.120070  173.173798
# 1  2015-01-05 00:00:00-05:00  172.111583  172.280176  169.734381  170.046280
# 2  2015-01-06 00:00:00-05:00  170.358216  170.889299  167.635388  168.444656
# 3  2015-01-07 00:00:00-05:00  169.793387  170.889266  169.338182  170.543640
# 4  2015-01-08 00:00:00-05:00  171.976772  173.789191  171.959921  173.570007
#
#       Volume  Dividends  Stock Splits  Capital Gains  Daily_Return  MA20  \
# 0  121465900        0.0           0.0            0.0           NaN   NaN
# 1  169632600        0.0           0.0            0.0     -0.018060   NaN
# 2  209151400        0.0           0.0            0.0     -0.009419   NaN
# 3  125346700        0.0           0.0            0.0      0.012461   NaN
# 4  147217800        0.0           0.0            0.0      0.017745   NaN
#
#    MA50  MA200  Volatility
# 0   NaN    NaN         NaN
# 1   NaN    NaN         NaN
# 2   NaN    NaN         NaN
# 3   NaN    NaN         NaN
# 4   NaN    NaN         NaN

# %%
df_SPY.isnull().sum()
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Volume             0
# Dividends          0
# Stock Splits       0
# Capital Gains      0
# Daily_Return       1
# MA20              19
# MA50              49
# MA200            199
# Volatility        20
# dtype: int64

# %%
# apply mean to NaN values 
dfs = [df_TSLA, df_SPY, df_BND]

# List of columns to apply the mean calculation
columns = ['MA20', 'MA50', 'MA200', 'Daily_Return', 'Volatility']

# Apply the mean calculation to rows with NaN values for each dataset
for df in dfs:
    for col in columns:
        mean_value = df[col].mean()  # Calculate the mean of the column
        df[col].fillna(mean_value, inplace=True)  # Replace NaN values with the mean

# %%
df_TSLA['Date'] = pd.to_datetime(df_TSLA['Date'])
#df_TSLA.set_index('Date', inplace=True)

df_BND['Date'] = pd.to_datetime(df_BND['Date'])
#df_BND.set_index('Date', inplace=True)

df_SPY['Date'] = pd.to_datetime(df_SPY['Date'])
#df_SPY.set_index('Date', inplace=True)

# %%
df_TSLA.to_csv('../data/processed/TSLA_processed.csv',index=False)
df_SPY.to_csv('../data/processed/SPY_processed.csv',index=False)
df_BND.to_csv('../data/processed/BND_processed.csv',index=False)

# %%
df_TSLA.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2487.000000  2487.000000  2487.000000  2487.000000  2.487000e+03
# mean    112.438754   114.904128   109.816698   112.416220  1.126303e+08
# std     110.775715   113.242157   108.081678   110.688731  7.438799e+07
# min       9.488000    10.331333     9.403333     9.578000  1.062000e+07
# 25%      17.117001    17.392334    16.801000    17.126333  6.685095e+07
# 50%      25.199333    25.666668    24.846666    25.304667  9.311550e+07
# 75%     218.675003   222.703339   213.165001   218.359993  1.303515e+08
# max     411.470001   414.496674   405.666656   409.970001  9.140820e+08
#
#        Dividends  Stock Splits  Daily_Return         MA20         MA50  \
# count     2487.0   2487.000000   2487.000000  2487.000000  2487.000000
# mean         0.0      0.003217      0.001910   112.066128   111.844028
# std          0.0      0.116903      0.035983   109.309182   107.695819
# min          0.0      0.000000     -0.210628    11.276033    12.683800
# 25%          0.0      0.000000     -0.016168    17.264417    17.335993
# 50%          0.0      0.000000      0.001262    27.359033    37.887387
# 75%          0.0      0.000000      0.019051   219.870667   220.030834
# max          0.0      5.000000      0.219190   373.152498   357.870532
#
#              MA200   Volatility
# count  2487.000000  2487.000000
# mean    111.726126     0.522614
# std     101.726421     0.219381
# min      14.161390     0.156555
# 25%      19.143492     0.361470
# 50%      66.853513     0.477835
# 75%     210.259733     0.625117
# max     304.789333     1.591712

# %%
df_BND.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2487.000000  2487.000000  2487.000000  2487.000000  2.487000e+03
# mean     69.902874    70.001762    69.795345    69.899658  4.183851e+06
# std       4.869191     4.876517     4.858302     4.868438  2.789498e+06
# min      62.484154    62.530478    62.414661    62.453266  0.000000e+00
# 25%      66.124333    66.223217    66.060322    66.146492  2.031450e+06
# 50%      68.791186    68.907473    68.627940    68.727852  3.728400e+06
# 75%      73.564082    73.661515    73.457002    73.591248  5.545800e+06
# max      79.640336    79.675904    79.542535    79.578110  3.193720e+07
#
#          Dividends  Stock Splits  Capital Gains  Daily_Return         MA20  \
# count  2487.000000        2487.0         2487.0   2487.000000  2487.000000
# mean      0.008616           0.0            0.0      0.000062    69.912960
# std       0.039522           0.0            0.0      0.003432     4.832276
# min       0.000000           0.0            0.0     -0.054385    62.714104
# 25%       0.000000           0.0            0.0     -0.001511    66.201720
# 50%       0.000000           0.0            0.0      0.000124    68.937439
# 75%       0.000000           0.0            0.0      0.001728    73.535225
# max       0.369000           0.0            0.0      0.042201    79.212554
#
#               MA50        MA200   Volatility
# count  2487.000000  2487.000000  2487.000000
# mean     69.928330    70.057210     0.044874
# std       4.773175     4.448764     0.031213
# min      62.898440    63.348004     0.013866
# 25%      66.307822    66.469854     0.027843
# 50%      68.959325    68.966997     0.036061
# 75%      73.418530    73.230791     0.054217
# max      78.926078    78.480487     0.317330

# %%
df_SPY.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2487.000000  2487.000000  2487.000000  2487.000000  2.487000e+03
# mean    311.651705   313.348040   309.806010   311.699813  8.789357e+07
# std     112.732976   113.305274   112.093381   112.743371  4.490030e+07
# min     156.881198   158.395471   155.197496   157.328598  2.027000e+07
# 25%     215.212629   215.673157   214.299044   215.025269  5.944230e+07
# 50%     276.284112   277.353049   274.809710   276.228821  7.676870e+07
# 75%     403.442849   405.099295   400.615367   403.131256  1.024638e+08
# max     599.809998   600.169983   597.000000   598.760010  5.072443e+08
#
#          Dividends  Stock Splits  Capital Gains  Daily_Return         MA20  \
# count  2487.000000        2487.0         2487.0   2487.000000  2487.000000
# mean      0.021603           0.0            0.0      0.000554   311.177554
# std       0.173752           0.0            0.0      0.011129   110.931897
# min       0.000000           0.0            0.0     -0.109424   162.086472
# 25%       0.000000           0.0            0.0     -0.003707   215.830180
# 50%       0.000000           0.0            0.0      0.000596   275.273862
# 75%       0.000000           0.0            0.0      0.005931   402.152455
# max       1.906000           0.0            0.0      0.090603   584.666501
#
#               MA50        MA200   Volatility
# count  2487.000000  2487.000000  2487.000000
# mean    310.384062   307.097068     0.147990
# std     108.205452    96.112679     0.098156
# min     166.145729   172.508045     0.031905
# 25%     217.228902   231.180543     0.089664
# 50%     278.667680   290.031830     0.121771
# 75%     398.079318   392.789755     0.184777
# max     576.161653   537.885514     0.931851
